# %% [markdown]
# # Batch Features
#
# ## Problem Statement
#
# Scenario: We're a utility company providing energy to New York City.
#
# Goal: Every day, we want to accurately predict the energy demand for the next three days so that we can optimally plan our resources.
#
# Task: We will look at historic energy demand and create batch features that we can use to predict the future demand.

# %% [markdown]
# ## Prerequisites

# %%
import pandas as pd

# %% [markdown]
# ## Data
#
# Let's explore our data!

# %%
import pandas as pd

# %%
csv_file_path = 'data/energy_data.csv'

# %%
import requests
import os

# %%
# get the EIA API key form your secrets
API_KEY = '0P8HueuW8Nr7cpOpLObajcFyScHEmt9SMdkYDzGN'

# %%
# API URL
url = "https://api.eia.gov/v2/electricity/rto/region-sub-ba-data/data/?frequency=hourly&data[0]=value&facets[subba][]=ZONJ&start=2024-01-01T00&end=2024-03-30T23&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key="+API_KEY

# %%
# Make a GET request
response = requests.get(url)
data = response.json()  # Decode the JSON response into a dictionary

# %%
# Extract data from the response
energy_data = data['response']['data']
df = pd.DataFrame(energy_data)
df.to_csv(csv_file_path, index=False)

# %%
# Load DataFrame from CSV
df = pd.read_csv(csv_file_path, parse_dates=['period']).set_index('period')

# Display the DataFrame
df.head()
# Out:
#                     subba            subba-name parent  \
# period
# 2024-03-30 00:00:00  ZONJ  New York City - NYIS   NYIS
# 2024-03-29 23:00:00  ZONJ  New York City - NYIS   NYIS
# 2024-03-29 22:00:00  ZONJ  New York City - NYIS   NYIS
# 2024-03-29 21:00:00  ZONJ  New York City - NYIS   NYIS
# 2024-03-29 20:00:00  ZONJ  New York City - NYIS   NYIS
#
#                                               parent-name  value  \
# period
# 2024-03-30 00:00:00  New York Independent System Operator   5418
# 2024-03-29 23:00:00  New York Independent System Operator   5391
# 2024-03-29 22:00:00  New York Independent System Operator   5408
# 2024-03-29 21:00:00  New York Independent System Operator   5338
# 2024-03-29 20:00:00  New York Independent System Operator   5276
#
#                        value-units
# period
# 2024-03-30 00:00:00  megawatthours
# 2024-03-29 23:00:00  megawatthours
# 2024-03-29 22:00:00  megawatthours
# 2024-03-29 21:00:00  megawatthours
# 2024-03-29 20:00:00  megawatthours

# %%
# Aggreggate by day:
df_daily = df.resample('D').sum("value")
df_daily
# Out:
#              value
# period
# 2024-01-01  116406
# 2024-01-02  128866
# 2024-01-03  131883
# 2024-01-04  131606
# 2024-01-05  136960
# ...            ...
# 2024-03-26  125493
# 2024-03-27  125867
# 2024-03-28  125577
# 2024-03-29  120926
# 2024-03-30    5418
#
# [90 rows x 1 columns]

# %%
# Inspect time series
df_daily.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='period'>

# %%
# Aggreggate by day:
df_daily = df.resample('D').sum("value")
df_daily
# Out:
#              value
# period
# 2024-01-01  116406
# 2024-01-02  128866
# 2024-01-03  131883
# 2024-01-04  131606
# 2024-01-05  136960
# ...            ...
# 2024-03-26  125493
# 2024-03-27  125867
# 2024-03-28  125577
# 2024-03-29  120926
# 2024-03-30    5418
#
# [90 rows x 1 columns]

# %%
# Inspect time series
df_daily.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='period'>

# %%
batch_df = pd.DataFrame()

# Lagging features
batch_df['lag_1'] = df_daily['value'].shift(1) # Energy demand -1 day

batch_df['lag_4'] = df_daily['value'].shift(4) # Energy demand +3 days - 7 days
batch_df['lag_5'] = df_daily['value'].shift(5) # Energy demand +2 days - 7 days
batch_df['lag_6'] = df_daily['value'].shift(6) # Energy demand +1 days - 7 days

batch_df['lag_11'] = df_daily['value'].shift(11) # Energy demand +3 days - 14 days
batch_df['lag_12'] = df_daily['value'].shift(12) # Energy demand +2 days - 14 days
batch_df['lag_13'] = df_daily['value'].shift(13) # Energy demand +1 days - 14 days

batch_df.head(14)
# Out:
#                lag_1     lag_4     lag_5     lag_6    lag_11    lag_12  \
# period
# 2024-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-01-02  116406.0       NaN       NaN       NaN       NaN       NaN
# 2024-01-03  128866.0       NaN       NaN       NaN       NaN       NaN
# 2024-01-04  131883.0       NaN       NaN       NaN       NaN       NaN
# 2024-01-05  131606.0  116406.0       NaN       NaN       NaN       NaN
# 2024-01-06  136960.0  128866.0  116406.0       NaN       NaN       NaN
# 2024-01-07  130213.0  131883.0  128866.0  116406.0       NaN       NaN
# 2024-01-08  126933.0  131606.0  131883.0  128866.0       NaN       NaN
# 2024-01-09  132752.0  136960.0  131606.0  131883.0       NaN       NaN
# 2024-01-10  134119.0  130213.0  136960.0  131606.0       NaN       NaN
# 2024-01-11  129372.0  126933.0  130213.0  136960.0       NaN       NaN
# 2024-01-12  129308.0  132752.0  126933.0  130213.0  116406.0       NaN
# 2024-01-13  128467.0  134119.0  132752.0  126933.0  128866.0  116406.0
# 2024-01-14  119134.0  129372.0  134119.0  132752.0  131883.0  128866.0
#
#               lag_13
# period
# 2024-01-01       NaN
# 2024-01-02       NaN
# 2024-01-03       NaN
# 2024-01-04       NaN
# 2024-01-05       NaN
# 2024-01-06       NaN
# 2024-01-07       NaN
# 2024-01-08       NaN
# 2024-01-09       NaN
# 2024-01-10       NaN
# 2024-01-11       NaN
# 2024-01-12       NaN
# 2024-01-13       NaN
# 2024-01-14  116406.0

# %%
# Rolling statistics
batch_df['rolling_mean_7'] = df_daily['value'].rolling(window=7).mean().round(2)
batch_df['rolling_std_7'] = df_daily['value'].rolling(window=7).std().round(2)

batch_df.head(7)
# Out:
#                lag_1     lag_4     lag_5     lag_6  lag_11  lag_12  lag_13  \
# period
# 2024-01-01       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 2024-01-02  116406.0       NaN       NaN       NaN     NaN     NaN     NaN
# 2024-01-03  128866.0       NaN       NaN       NaN     NaN     NaN     NaN
# 2024-01-04  131883.0       NaN       NaN       NaN     NaN     NaN     NaN
# 2024-01-05  131606.0  116406.0       NaN       NaN     NaN     NaN     NaN
# 2024-01-06  136960.0  128866.0  116406.0       NaN     NaN     NaN     NaN
# 2024-01-07  130213.0  131883.0  128866.0  116406.0     NaN     NaN     NaN
#
#             rolling_mean_7  rolling_std_7
# period
# 2024-01-01             NaN            NaN
# 2024-01-02             NaN            NaN
# 2024-01-03             NaN            NaN
# 2024-01-04             NaN            NaN
# 2024-01-05             NaN            NaN
# 2024-01-06             NaN            NaN
# 2024-01-07        128981.0        6361.77

# %%
# Inspect target variable - it's actually 3!

# Lagging target variable
batch_df['target_1d'] = df_daily['value'].shift(-1) # Next day
batch_df['target_2d'] = df_daily['value'].shift(-2) # Second-next day
batch_df['target_3d'] = df_daily['value'].shift(-3) # Third-next day

batch_df.head(15)
# Out:
#                lag_1     lag_4     lag_5     lag_6    lag_11    lag_12  \
# period
# 2024-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-01-02  116406.0       NaN       NaN       NaN       NaN       NaN
# 2024-01-03  128866.0       NaN       NaN       NaN       NaN       NaN
# 2024-01-04  131883.0       NaN       NaN       NaN       NaN       NaN
# 2024-01-05  131606.0  116406.0       NaN       NaN       NaN       NaN
# 2024-01-06  136960.0  128866.0  116406.0       NaN       NaN       NaN
# 2024-01-07  130213.0  131883.0  128866.0  116406.0       NaN       NaN
# 2024-01-08  126933.0  131606.0  131883.0  128866.0       NaN       NaN
# 2024-01-09  132752.0  136960.0  131606.0  131883.0       NaN       NaN
# 2024-01-10  134119.0  130213.0  136960.0  131606.0       NaN       NaN
# 2024-01-11  129372.0  126933.0  130213.0  136960.0       NaN       NaN
# 2024-01-12  129308.0  132752.0  126933.0  130213.0  116406.0       NaN
# 2024-01-13  128467.0  134119.0  132752.0  126933.0  128866.0  116406.0
# 2024-01-14  119134.0  129372.0  134119.0  132752.0  131883.0  128866.0
# 2024-01-15  121604.0  129308.0  129372.0  134119.0  131606.0  131883.0
#
#               lag_13  rolling_mean_7  rolling_std_7  target_1d  target_2d  \
# period
# 2024-01-01       NaN             NaN            NaN   128866.0   131883.0
# 2024-01-02       NaN             NaN            NaN   131883.0   131606.0
# 2024-01-03       NaN             NaN            NaN   131606.0   136960.0
# 2024-01-04       NaN             NaN            NaN   136960.0   130213.0
# 2024-01-05       NaN             NaN            NaN   130213.0   126933.0
# 2024-01-06       NaN             NaN            NaN   126933.0   132752.0
# 2024-01-07       NaN       128981.00        6361.77   132752.0   134119.0
# 2024-01-08       NaN       131316.14        3182.04   134119.0   129372.0
# 2024-01-09       NaN       132066.57        3126.85   129372.0   129308.0
# 2024-01-10       NaN       131707.86        3291.13   129308.0   128467.0
# 2024-01-11       NaN       131379.57        3415.26   128467.0   119134.0
# 2024-01-12       NaN       130166.29        2483.99   119134.0   121604.0
# 2024-01-13       NaN       128583.57        4851.04   121604.0   136704.0
# 2024-01-14  116406.0       127822.29        5524.62   136704.0   145628.0
# 2024-01-15  128866.0       128386.86        6264.72   145628.0   151329.0
#
#             target_3d
# period
# 2024-01-01   131606.0
# 2024-01-02   136960.0
# 2024-01-03   130213.0
# 2024-01-04   126933.0
# 2024-01-05   132752.0
# 2024-01-06   134119.0
# 2024-01-07   129372.0
# 2024-01-08   129308.0
# 2024-01-09   128467.0
# 2024-01-10   119134.0
# 2024-01-11   121604.0
# 2024-01-12   136704.0
# 2024-01-13   145628.0
# 2024-01-14   151329.0
# 2024-01-15   146188.0

# %%
# check targets
df_daily.head(4)
# Out:
#              value
# period
# 2024-01-01  116406
# 2024-01-02  128866
# 2024-01-03  131883
# 2024-01-04  131606

# %%
# Drop NaN-values
batch_df = batch_df.dropna()
batch_df
# Out:
#                lag_1     lag_4     lag_5     lag_6    lag_11    lag_12  \
# period
# 2024-01-14  119134.0  129372.0  134119.0  132752.0  131883.0  128866.0
# 2024-01-15  121604.0  129308.0  129372.0  134119.0  131606.0  131883.0
# 2024-01-16  136704.0  128467.0  129308.0  129372.0  136960.0  131606.0
# 2024-01-17  145628.0  119134.0  128467.0  129308.0  130213.0  136960.0
# 2024-01-18  151329.0  121604.0  119134.0  128467.0  126933.0  130213.0
# ...              ...       ...       ...       ...       ...       ...
# 2024-03-23  130956.0  125016.0  118592.0  107680.0  124289.0  127532.0
# 2024-03-24  122277.0  124910.0  125016.0  118592.0  120013.0  124289.0
# 2024-03-25  118230.0  129138.0  124910.0  125016.0  120293.0  120013.0
# 2024-03-26  126118.0  130956.0  129138.0  124910.0  119478.0  120293.0
# 2024-03-27  125493.0  122277.0  130956.0  129138.0  109879.0  119478.0
#
#               lag_13  rolling_mean_7  rolling_std_7  target_1d  target_2d  \
# period
# 2024-01-14  116406.0       127822.29        5524.62   136704.0   145628.0
# 2024-01-15  128866.0       128386.86        6264.72   145628.0   151329.0
# 2024-01-16  131883.0       130031.00        8953.19   151329.0   146188.0
# 2024-01-17  131606.0       133167.71       12008.71   146188.0   147359.0
# 2024-01-18  136960.0       135579.14       12774.85   147359.0   144471.0
# ...              ...             ...            ...        ...        ...
# 2024-03-23  116906.0       122652.71        7772.78   118230.0   126118.0
# 2024-03-24  127532.0       124159.86        4864.40   126118.0   125493.0
# 2024-03-25  124289.0       125235.00        4217.35   125493.0   125867.0
# 2024-03-26  120013.0       125303.14        4217.08   125867.0   125577.0
# 2024-03-27  120293.0       125439.86        4217.72   125577.0   120926.0
#
#             target_3d
# period
# 2024-01-14   151329.0
# 2024-01-15   146188.0
# 2024-01-16   147359.0
# 2024-01-17   144471.0
# 2024-01-18   143686.0
# ...               ...
# 2024-03-23   125493.0
# 2024-03-24   125867.0
# 2024-03-25   125577.0
# 2024-03-26   120926.0
# 2024-03-27     5418.0
#
# [74 rows x 12 columns]

# %%
# Check correlation matrix. 
# Ideally we want low correlation between features, but high correlation between features and target

corr = batch_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7c2e9_row0_col0, #T_7c2e9_row1_col1, #T_7c2e9_row2_col2, #T_7c2e9_row3_col3, #T_7c2e9_row4_col4, #T_7c2e9_row5_col5, #T_7c2e9_row6_col6, #T_7c2e9_row7_col7, #T_7c2e9_row8_col8, #T_7c2e9_row9_col9, #T_7c2e9_row10_col10, #T_7c2e9_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7c2e9_row0_col1, #T_7c2e9_row0_col8, #T_7c2e9_row1_col4 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_7c2e9_row0_col2, #T_7c2e9_row3_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_7c2e9_row0_col3, #T_7c2e9_row11_col10 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_7c2e9_row0_col4, #T_7c2e9_row0_col5, #T_7c2e9_row0_col10, #T_7c2e9_row1_col6, #T_7c2e9_row2_col8, #T_7c2e9_row3_col10, #T_7c2e9_row3_col11, #T_7c2e9_row4_col9, #T_7c2e9_row5_col0, #T_7c2e9_row8_col1, #T_7c2e9_row8_col2, #T_7c2e9_row8_col3, #T_7c2e9_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7c2e9_row0_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_7c2e9_row0_col7 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_7c2e9_row0_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_7c2e9_row0_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_7c2e9_row1_col0, #T_7c2e9_row8_col10 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_7c2e9_row1_col2, #T_7c2e9_row2_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_7c2e9_row1_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_7c2e9_row1_col5, #T_7c2e9_row5_col9 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_7c2e9_row1_col7 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_7c2e9_row1_col8 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_7c2e9_row1_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_7c2e9_row1_col10, #T_7c2e9_row4_col0, #T_7c2e9_row6_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7c2e9_row1_col11, #T_7c2e9_row8_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_7c2e9_row2_col0, #T_7c2e9_row2_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_7c2e9_row2_col1, #T_7c2e9_row7_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_7c2e9_row2_col4, #T_7c2e9_row10_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_7c2e9_row2_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_7c2e9_row2_col7 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_7c2e9_row2_col9, #T_7c2e9_row7_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_7c2e9_row2_col10 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_7c2e9_row2_col11, #T_7c2e9_row4_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_7c2e9_row3_col0, #T_7c2e9_row3_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_7c2e9_row3_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_7c2e9_row3_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_7c2e9_row3_col5, #T_7c2e9_row9_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_7c2e9_row3_col7 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_7c2e9_row3_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_7c2e9_row3_col9, #T_7c2e9_row9_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_7c2e9_row4_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_7c2e9_row4_col2, #T_7c2e9_row4_col6 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_7c2e9_row4_col3, #T_7c2e9_row10_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_7c2e9_row4_col5, #T_7c2e9_row5_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_7c2e9_row4_col7 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_7c2e9_row4_col8 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_7c2e9_row4_col11 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_7c2e9_row5_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_7c2e9_row5_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_7c2e9_row5_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_7c2e9_row5_col6 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_7c2e9_row5_col7, #T_7c2e9_row11_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_7c2e9_row5_col8, #T_7c2e9_row6_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_7c2e9_row5_col10 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_7c2e9_row5_col11, #T_7c2e9_row11_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_7c2e9_row6_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_7c2e9_row6_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_7c2e9_row6_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_7c2e9_row6_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_7c2e9_row6_col4, #T_7c2e9_row9_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_7c2e9_row6_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_7c2e9_row6_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_7c2e9_row6_col8, #T_7c2e9_row8_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_7c2e9_row6_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_7c2e9_row7_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_7c2e9_row7_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_7c2e9_row7_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_7c2e9_row7_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_7c2e9_row7_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_7c2e9_row7_col6 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7c2e9_row7_col9 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_7c2e9_row7_col10 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_7c2e9_row7_col11, #T_7c2e9_row11_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_7c2e9_row8_col4, #T_7c2e9_row8_col11 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_7c2e9_row8_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7c2e9_row8_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7c2e9_row9_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_7c2e9_row9_col3, #T_7c2e9_row9_col8, #T_7c2e9_row10_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_7c2e9_row9_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_7c2e9_row9_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_7c2e9_row9_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_7c2e9_row9_col10 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_7c2e9_row9_col11 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_7c2e9_row10_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_7c2e9_row10_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_7c2e9_row10_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_7c2e9_row10_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7c2e9_row10_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_7c2e9_row10_col8 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_7c2e9_row10_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_7c2e9_row10_col11, #T_7c2e9_row11_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_7c2e9_row11_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_7c2e9_row11_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_7c2e9_row11_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_7c2e9_row11_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_7c2e9_row11_col8 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_7c2e9_row11_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c2e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c2e9_level0_col0" class="col_heading level0 col0" >lag_1</th>
#       <th id="T_7c2e9_level0_col1" class="col_heading level0 col1" >lag_4</th>
#       <th id="T_7c2e9_level0_col2" class="col_heading level0 col2" >lag_5</th>
#       <th id="T_7c2e9_level0_col3" class="col_heading level0 col3" >lag_6</th>
#       <th id="T_7c2e9_level0_col4" class="col_heading level0 col4" >lag_11</th>
#       <th id="T_7c2e9_level0_col5" class="col_heading level

# %%
# Load DataFrame from CSV
df = pd.read_csv(csv_file_path, parse_dates=['period'])
df.set_index('period', inplace=True)

# Run the feature pipeline
from scripts import feature_processing
feature_processing.feature_pipeline(df)
# Out:
#                lag_1     lag_4     lag_5     lag_6    lag_11    lag_12  \
# period
# 2024-01-14  119134.0  129372.0  134119.0  132752.0  131883.0  128866.0
# 2024-01-15  121604.0  129308.0  129372.0  134119.0  131606.0  131883.0
# 2024-01-16  136704.0  128467.0  129308.0  129372.0  136960.0  131606.0
# 2024-01-17  145628.0  119134.0  128467.0  129308.0  130213.0  136960.0
# 2024-01-18  151329.0  121604.0  119134.0  128467.0  126933.0  130213.0
# ...              ...       ...       ...       ...       ...       ...
# 2024-03-26  126118.0  130956.0  129138.0  124910.0  119478.0  120293.0
# 2024-03-27  125493.0  122277.0  130956.0  129138.0  109879.0  119478.0
# 2024-03-28  125867.0  118230.0  122277.0  130956.0  107680.0  109879.0
# 2024-03-29  125577.0  126118.0  118230.0  122277.0  118592.0  107680.0
# 2024-03-30  120926.0  125493.0  126118.0  118230.0  125016.0  118592.0
#
#               lag_13  rolling_mean_7  rolling_std_7
# period
# 2024-01-14  116406.0       127822.29        5524.62
# 2024-01-15  128866.0       128386.86        6264.72
# 2024-01-16  131883.0       130031.00        8953.19
# 2024-01-17  131606.0       133167.71       12008.71
# 2024-01-18  136960.0       135579.14       12774.85
# ...              ...             ...            ...
# 2024-03-26  120013.0       125303.14        4217.08
# 2024-03-27  120293.0       125439.86        4217.72
# 2024-03-28  119478.0       124931.14        3900.13
# 2024-03-29  109879.0       123498.29        3072.37
# 2024-03-30  107680.0       106804.14       44809.30
#
# [77 rows x 9 columns]

# %%
# Calculate targets
feature_processing.get_targets(df)
# Out:
#             target_1d  target_2d  target_3d
# period
# 2024-01-01   128866.0   131883.0   131606.0
# 2024-01-02   131883.0   131606.0   136960.0
# 2024-01-03   131606.0   136960.0   130213.0
# 2024-01-04   136960.0   130213.0   126933.0
# 2024-01-05   130213.0   126933.0   132752.0
# ...               ...        ...        ...
# 2024-03-23   118230.0   126118.0   125493.0
# 2024-03-24   126118.0   125493.0   125867.0
# 2024-03-25   125493.0   125867.0   125577.0
# 2024-03-26   125867.0   125577.0   120926.0
# 2024-03-27   125577.0   120926.0     5418.0
#
# [87 rows x 3 columns]
